# %% [markdown]
# <a id='table-of-contents'></a>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Project-goals" data-toc-modified-id="Project-goals-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Project goals</a></span></li><li><span><a href="#Scopes" data-toc-modified-id="Scopes-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Scopes</a></span></li><li><span><a href="#Key-results" data-toc-modified-id="Key-results-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Key results</a></span></li></ul></li><li><span><a href="#Loading-and-exploring-the-data" data-toc-modified-id="Loading-and-exploring-the-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Loading and exploring the data</a></span></li><li><span><a href="#Data-cleaning" data-toc-modified-id="Data-cleaning-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data cleaning</a></span><ul class="toc-item"><li><span><a href="#Renaming-columns" data-toc-modified-id="Renaming-columns-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Renaming columns</a></span></li><li><span><a href="#Converting-the-data-type-of-the-Time-column-to-datetime" data-toc-modified-id="Converting-the-data-type-of-the-Time-column-to-datetime-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Converting the data type of the <code>Time</code> column to <code>datetime</code></a></span></li><li><span><a href="#Isolating-the-Time-and-the-US_dollar-columns" data-toc-modified-id="Isolating-the-Time-and-the-US_dollar-columns-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Isolating the <code>Time</code> and the <code>US_dollar</code> columns</a></span></li><li><span><a href="#Removing-non-numeric-values" data-toc-modified-id="Removing-non-numeric-values-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Removing non-numeric values</a></span></li></ul></li><li><span><a href="#Generating-a-line-plot-by-using-rolling-mean" data-toc-modified-id="Generating-a-line-plot-by-using-rolling-mean-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Generating a line plot by using rolling mean</a></span></li><li><span><a href="#Isolating-the-lowest-and-highest-exchange-rate-per-year" data-toc-modified-id="Isolating-the-lowest-and-highest-exchange-rate-per-year-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Isolating the lowest and highest exchange rate per year</a></span></li><li><span><a href="#The-evolution-of-EURO-USD-exchange-rate:-events-and-crises-highlights" data-toc-modified-id="The-evolution-of-EURO-USD-exchange-rate:-events-and-crises-highlights-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>The evolution of EURO-USD exchange rate: events and crises highlights</a></span></li><li><span><a href="#The-evolution-of-the-EURO-USD-exchange-rate-under-the-last-three-US-presidents" data-toc-modified-id="The-evolution-of-the-EURO-USD-exchange-rate-under-the-last-three-US-presidents-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>The evolution of the EURO-USD exchange rate under the last three US presidents</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %% [markdown]
# # Data Visualization on Exchange Rates: Turning Risks into Opportunities  <a class=tocSkip>

# %% [markdown]
# ![ibrahim-boran-_aUwE2DnIPg-unsplash.jpg](attachment:ibrahim-boran-_aUwE2DnIPg-unsplash.jpg)

# %% [markdown]
# Photo by [Ibrahim Boran](https://unsplash.com/@ibrahimboran?utm_content=creditCopyText&utm_medium=referral&utm_source=unsplash) on [Unsplash](https://unsplash.com/@ibrahimboran?utm_content=creditCopyText&utm_medium=referral&utm_source=unsplash)

# %% [markdown]
# ## Introduction

# %% [markdown]
# This project focuses on the explanatory data visualization of the foreign exchange rate (FX-rate) between the euro (€) and the United States dollar (\\$).
#
# In the case of the EURO-USD exchange rate, the higher the rate, the stronger the value of the euro, and *vice versa*. For example, the euro is stronger at the exchange rate of 1.60 compared to 0.83, as one pays 1 euro to get 1.60 USD instead of 0.83 USD.
#
# We use a dataset of euro daily exchange rates from 1999-01-04 to 2021-01-08, which was compiled and published by Daria Chemkaeva on [Kaggle](https://www.kaggle.com/lsind18/euro-exchange-daily-rates-19992020). It is noteworthy that the dataset is updated regularly, and we are using the dataset downloaded in January 2021. The data was originally from the European Central Bank.

# %% [markdown]
# ### Project goals

# %% [markdown]
# This project aims to illustrate the evolution of the EURO-USD exchange rate from 1999 to 2021 via storytelling data visualisation.

# %% [markdown]
# ### Scopes

# %% [markdown]
# The project scopes include:
#
# - Data cleaning
# - Storytelling data visualisations

# %% [markdown]
# ### Key results

# %% [markdown]
# **EURO-USD FX-rate bottomed between 2000-2001** (during the 2000s recession) and **peaked in 2008** (during the financial crisis).
#
# **The Euro currency has been weak since 2015** due to multiple reasons, such as the European Central Bank's quantitative easing programme, the deepening of the European sovereign debt crisis, the likelihood of an increase in US interest rates, the 2019 global economic slowdown and the Covid-19 recession.

# %% [markdown]
# [Back to Table of Contents](#table-of-contents)

# %% [markdown]
# ---

# %% [markdown]
# ## Loading and exploring the data
# We set up the environment by importing the necessary libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Run the necessary Jupyter magic so that plots are displayed inline
# %matplotlib inline
import matplotlib.style as style

print('Packages were imported successfully!')
# Out:
# Packages were imported successfully!

# %% [markdown]
# We read the `euro-daily-hist_1999_2020.csv` dataset into a DataFrame and saved the results as  `exchange_rates`.

# %%
exchange_rates = pd.read_csv('euro-daily-hist_1999_2020.csv')

# %% [markdown]
# The column names are self-explanatory:
#
# - `Period\Unit:`: Date for the currency rate.
# - From `[Australian dollar]` to `[South African rand]`: The exchange rate of the euro to the specific currency.
#
# Let's briefly explore the dataset to get an overview of the dataset and determine the necessary basic data cleaning tasks.

# %%
exchange_rates
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0      2021-01-08               1.5758           1.9558            6.5748
# 1      2021-01-07               1.5836           1.9558            6.5172
# 2      2021-01-06               1.5824           1.9558            6.5119
# 3      2021-01-05               1.5927           1.9558            6.5517
# 4      2021-01-04               1.5928           1.9558            6.3241
# ...           ...                  ...              ...               ...
# 5694   1999-01-08               1.8406              NaN               NaN
# 5695   1999-01-07               1.8474              NaN               NaN
# 5696   1999-01-06               1.8820              NaN               NaN
# 5697   1999-01-05               1.8944              NaN               NaN
# 5698   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# ...

# %%
print('\033[1m' + 'Original dataset' + '\033[0m')
print('{:24} {:>6,}'.format('  - Number of rows:', exchange_rates.shape[0]))
print('{:24} {:>6,}'.format('  - Number of columns:', exchange_rates.shape[1]))
# Out:
# Original dataset
#   - Number of rows:       5,699
#   - Number of columns:       41

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5699 entries, 0 to 5698
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              5699 non-null   object
#  1   [Australian dollar ]      5699 non-null   object
#  2   [Bulgarian lev ]          5297 non-null   object
#  3   [Brazilian real ]         5431 non-null   object
#  4   [Canadian dollar ]        5699 non-null   object
#  5   [Swiss franc ]            5699 non-null   object
#  6   [Chinese yuan renminbi ]  5431 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           5699 non-null   object
#  9   [Danish krone ]           5699 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      5699 non-null   object
#  12  [Greek drachma ]          520 non-null    object
# ...

# %%
# Obtaining the sum of null values of each column
exchange_rates.isna().sum()
# Out:
# Period\Unit:                   0
# [Australian dollar ]           0
# [Bulgarian lev ]             402
# [Brazilian real ]            268
# [Canadian dollar ]             0
# [Swiss franc ]                 0
# [Chinese yuan renminbi ]     268
# [Cypriot pound ]            3353
# [Czech koruna ]                0
# [Danish krone ]                0
# [Estonian kroon ]           2569
# [UK pound sterling ]           0
# [Greek drachma ]            5179
# [Hong Kong dollar ]            0
# [Croatian kuna ]             268
# [Hungarian forint ]            0
# [Indonesian rupiah ]           0
# [Israeli shekel ]            268
# [Indian rupee ]              268
# [Iceland krona ]            2407
# [Japanese yen ]                0
# [Korean won ]                  0
# [Lithuanian litas ]         1540
# [Latvian lats ]             1795
# [Maltese lira ]             3353
# [Mexican peso ]                0
# [Malaysian ringgit ]           0
# [Norwegian krone ]             0
# ...

# %%
# Computing the total number of missing values in the dataset.
print('{:52} {:>6,}'.format('Total number of missing values in the dataset', exchange_rates.isnull().sum().sum()))
# Out:
# Total number of missing values in the dataset        28,767

# %% [markdown]
# The `exchange_rates` dataset contains 5,699 rows and 41 columns with the data sampling period from `2021-01-08` to `1999-01-04`.
#
# Our brief exploration shows that:
#
# - This dataset consists of `float` (3) and `object` (38).
# - The appropriate data type for `Period\Unit:` should be a `DateTime` object, and for all the currency rates should be `float`.
# - There are 28,767 null values in total. Nonetheless, there are no missing values in the US dollar, our currency of interest.

# %% [markdown]
# [Back to Table of Contents](#table-of-contents)

# %% [markdown]
# ---

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# Let's clean the data before we create data visualizations.

# %% [markdown]
# ### Renaming columns

# %% [markdown]
# We simplify and rename the `Period\Unit:` to `Time` and `[US dollar]` to `US_dollar`. Since we focus on the US dollar in this project, we do not rename other currency names.

# %%
# Rename column names
exchange_rates.rename(columns={'[US dollar ]':'US_dollar', 
                               'Period\\Unit:':'Time'}, inplace=True)

print(exchange_rates.columns)
# Out:
# Index(['Time', '[Australian dollar ]', '[Bulgarian lev ]', '[Brazilian real ]',
#        '[Canadian dollar ]', '[Swiss franc ]', '[Chinese yuan renminbi ]',
#        '[Cypriot pound ]', '[Czech koruna ]', '[Danish krone ]',
#        '[Estonian kroon ]', '[UK pound sterling ]', '[Greek drachma ]',
#        '[Hong Kong dollar ]', '[Croatian kuna ]', '[Hungarian forint ]',
#        '[Indonesian rupiah ]', '[Israeli shekel ]', '[Indian rupee ]',
#        '[Iceland krona ]', '[Japanese yen ]', '[Korean won ]',
#        '[Lithuanian litas ]', '[Latvian lats ]', '[Maltese lira ]',
#        '[Mexican peso ]', '[Malaysian ringgit ]', '[Norwegian krone ]',
#        '[New Zealand dollar ]', '[Philippine peso ]', '[Polish zloty ]',
#        '[Romanian leu ]', '[Russian rouble ]', '[Swedish krona ]',
#        '[Singapore dollar ]', '[Slovenian tolar ]', '[Slovak koruna ]',
#        '[Thai baht ]', '[Turkish lira ]', 'US_dollar',
#        '[South African rand ]'],
#       dtype='object')

# %% [markdown]
# ### Converting the data type of the `Time` column to `datetime`

# %% [markdown]
# We convert the `Time` column to the `datetime` data type.

# %%
# Convert to datetime
exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])

# %%
print(exchange_rates['Time'].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# Next, we sort the values in the `Time` column in an ascending order and reset the index.

# %%
# Sort values
exchange_rates.sort_values('Time', inplace=True)

# Reset the index and drop the initial index
exchange_rates.reset_index(drop=True, inplace=True)

exchange_rates.head()
# Out:
#         Time [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0 1999-01-04               1.9100              NaN               NaN
# 1 1999-01-05               1.8944              NaN               NaN
# 2 1999-01-06               1.8820              NaN               NaN
# 3 1999-01-07               1.8474              NaN               NaN
# 4 1999-01-08               1.8406              NaN               NaN
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.8004         1.6168                      NaN          0.58231
# 1             1.7965         1.6123                      NaN          0.58230
# 2             1.7711         1.6116                      NaN          0.58200
# 3             1.7602         1.6165                      NaN          0.58187
# 4             1.7643         1.6138                      NaN          0.58187
#
#   [Czech koruna ] [Danish krone ]  ... [Romanian leu ] [Russian rouble ]  \
# ...

# %% [markdown]
# ### Isolating the `Time` and the `US_dollar` columns

# %% [markdown]
# We isolate the `Time` and the `US_dollar` columns and assign them to the `euro_to_dollar` variable.

# %%
# Isolate columns
euro_to_dollar = exchange_rates[['Time', 'US_dollar']].copy()

# %%
euro_to_dollar.head()
# Out:
#         Time US_dollar
# 0 1999-01-04    1.1789
# 1 1999-01-05    1.1790
# 2 1999-01-06    1.1743
# 3 1999-01-07    1.1632
# 4 1999-01-08    1.1659

# %% [markdown]
# ### Removing non-numeric values

# %% [markdown]
# We inspected the values of `US_dollar` and found 62 entries of `-`, which are not numeric values.

# %%
euro_to_dollar['US_dollar'].value_counts()
# Out:
# -         62
# 1.2276     9
# 1.1215     8
# 1.1305     7
# 1.1797     6
#           ..
# 1.2571     1
# 1.2610     1
# 1.2651     1
# 1.2632     1
# 1.2193     1
# Name: US_dollar, Length: 3528, dtype: int64

# %% [markdown]
# `-` does not make sense for our data analysis. Therefore, we need to remove the rows with `-`.

# %%
# Remove the rows with non-numeric values
euro_to_dollar = euro_to_dollar[euro_to_dollar['US_dollar'] != '-']

# Verify the removal
euro_to_dollar['US_dollar'].value_counts()
# Out:
# 1.2276    9
# 1.1215    8
# 1.1305    7
# 1.3373    6
# 1.3532    6
#          ..
# 1.2571    1
# 1.2610    1
# 1.2651    1
# 1.2632    1
# 1.2193    1
# Name: US_dollar, Length: 3527, dtype: int64

# %% [markdown]
# Since the original data type of `US_dollar` is `object`, we convert it to `float` for data analysis and visualization.

# %%
# Convert the data type of `US_dollar` to `float`
euro_to_dollar['US_dollar'] = euro_to_dollar['US_dollar'].astype(float)

# %%
# Verify the conversion
euro_to_dollar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5637 entries, 0 to 5698
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       5637 non-null   datetime64[ns]
#  1   US_dollar  5637 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 132.1 KB

# %% [markdown]
# [Back to Table of Contents](#table-of-contents)

# %% [markdown]
# ---

# %% [markdown]
# ## Generating a line plot by using rolling mean

# %% [markdown]
# We visualise the change of the EURO-USD exchange rate over time by using a line plot.

# %%
plt.plot(euro_to_dollar['Time'], euro_to_dollar['US_dollar'])

plt.show()

# %% [markdown]
# Instead of a smooth line, we observe many tiny fluctuations at the line of our line plot, which is due to the daily variation in the exchange rate. Since we are more interested in the long-term trend of the exchange rate, we will use a _rolling mean_ with a _rolling window of 30 days_ (one month) to generate the line plot.
#
# To do this, we compute the rolling mean and assign it to a new column named `rolling_mean`.

# %%
# Compute the rolling mean with a rolling window of 30
euro_to_dollar['rolling_mean'] = euro_to_dollar['US_dollar'].rolling(30).mean()

# %%
euro_to_dollar
# Out:
#            Time  US_dollar  rolling_mean
# 0    1999-01-04     1.1789           NaN
# 1    1999-01-05     1.1790           NaN
# 2    1999-01-06     1.1743           NaN
# 3    1999-01-07     1.1632           NaN
# 4    1999-01-08     1.1659           NaN
# ...         ...        ...           ...
# 5694 2021-01-04     1.2296      1.211170
# 5695 2021-01-05     1.2271      1.212530
# 5696 2021-01-06     1.2338      1.213987
# 5697 2021-01-07     1.2276      1.215357
# 5698 2021-01-08     1.2250      1.216557
#
# [5637 rows x 3 columns]

# %% [markdown]
# Now, let's generate a smoother line plot with a rolling window of 30 days.

# %%
plt.plot(euro_to_dollar['Time'], euro_to_dollar['rolling_mean'])

plt.show()

# %% [markdown]
# [Back to Table of Contents](#table-of-contents)

# %% [markdown]
# ---

# %% [markdown]
# ## Isolating the lowest and highest exchange rate per year

# %% [markdown]
# We compute the lowest and the highest exchange rate by the year to get a better idea about the currency fluctuations. To do that, we perform these steps:
# - We isolate the *years* from `Time` and assign them to a new column named `Year`.
# - We use `df.pivot_table()` to compute the *minimum and maximum exchange rate per year*.

# %%
# Isolate years
euro_to_dollar['Year'] = euro_to_dollar['Time'].dt.year

euro_to_dollar
# Out:
#            Time  US_dollar  rolling_mean  Year
# 0    1999-01-04     1.1789           NaN  1999
# 1    1999-01-05     1.1790           NaN  1999
# 2    1999-01-06     1.1743           NaN  1999
# 3    1999-01-07     1.1632           NaN  1999
# 4    1999-01-08     1.1659           NaN  1999
# ...         ...        ...           ...   ...
# 5694 2021-01-04     1.2296      1.211170  2021
# 5695 2021-01-05     1.2271      1.212530  2021
# 5696 2021-01-06     1.2338      1.213987  2021
# 5697 2021-01-07     1.2276      1.215357  2021
# 5698 2021-01-08     1.2250      1.216557  2021
#
# [5637 rows x 4 columns]

# %%
# Extract the minimum exchange rate for each year
min_euro_to_dollar = euro_to_dollar.pivot_table(values='US_dollar', index='Year', 
                                                aggfunc=np.min)

min_euro_to_dollar
# Out:
#       US_dollar
# Year
# 1999     1.0015
# 2000     0.8252
# 2001     0.8384
# 2002     0.8578
# 2003     1.0377
# 2004     1.1802
# 2005     1.1667
# 2006     1.1826
# 2007     1.2893
# 2008     1.2460
# 2009     1.2555
# 2010     1.1942
# 2011     1.2889
# 2012     1.2089
# 2013     1.2768
# 2014     1.2141
# 2015     1.0552
# 2016     1.0364
# 2017     1.0385
# 2018     1.1261
# 2019     1.0889
# 2020     1.0707
# 2021     1.2250

# %%
# Extract the maximum exchange rate for each year
max_euro_to_dollar = euro_to_dollar.pivot_table(values='US_dollar', index='Year', 
                                                aggfunc=np.max)

max_euro_to_dollar
# Out:
#       US_dollar
# Year
# 1999     1.1790
# 2000     1.0388
# 2001     0.9545
# 2002     1.0487
# 2003     1.2630
# 2004     1.3633
# 2005     1.3507
# 2006     1.3331
# 2007     1.4874
# 2008     1.5990
# 2009     1.5120
# 2010     1.4563
# 2011     1.4882
# 2012     1.3454
# 2013     1.3814
# 2014     1.3953
# 2015     1.2043
# 2016     1.1569
# 2017     1.2060
# 2018     1.2493
# 2019     1.1535
# 2020     1.2281
# 2021     1.2338

# %% [markdown]
# [Back to Table of Contents](#table-of-contents)

# %% [markdown]
# ---

# %% [markdown]
# ## The evolution of EURO-USD exchange rate: events and crises highlights

# %% [markdown]
# We highlight some events/crises that impacted on the EURO-USD exchange rate from 1999 to 2021 and visualise them on a line plot with *ggplot* Matplotlib style.

# %%
# Isolate the `years` of the early 2000s recession (2000 - 2002)
early2000s_recessions = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2000) 
                                              & (euro_to_dollar['Time'].dt.year < 2003)]

# Isolate the `years` of the financial crisis (2007 - 2009)
financial_crisis = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2007) 
                                              & (euro_to_dollar['Time'].dt.year < 2010)]

# Isolate the `years` of the European sovereign debt crisis (2015 - 2017)
eu_debt_crisis = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2015) 
                                              & (euro_to_dollar['Time'].dt.year < 2018)]

# Isolate the `years` of the 2019 global economic slowdown 
# and Covid-19 recession (2019 - 2020)
economic_slowdown_Covid = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2019) 
                                              & (euro_to_dollar['Time'].dt.year < 2021)]

# %%
# Add Matplotlib style
style.use('ggplot')

# Create a line plot
fig, ax = plt.subplots(figsize=(16,8))

ax.plot(euro_to_dollar['Time'], euro_to_dollar['rolling_mean'], 
        linewidth=1, color='grey')

# Set and labelling the xticks
ax.set_xticks(['1999', '2001', '2003', '2005', '2007', '2009',
               '2011', '2013', '2015', '2017', '2019', '2021'])
ax.set_xticklabels(['1999', '2001', '2003', '2005', '2007', '2009',
               '2011', '2013', '2015', '2017', '2019', '2021'])

# Set the facecolor of the axis to white
ax.set_facecolor(color='#ffffff')

# Change the color of grid to a lighter color
ax.grid(color='#f0f0f0')

# Hide ticks
ax.tick_params(bottom=False, left=False)

# Set the y limit
ax.set_ylim(0.8, 2.0)

# Reduce the y ticks 
ax.set_yticks([0.8, 1.0, 1.2, 1.4, 1.6])

# Set tick label color
ax.tick_params(colors='#9E9E9E', which='both')


# ----------------------------------------------------------------------------
# Highlight global economy crises

# Create a list for all the crises
events = [early2000s_recessions, financial_crisis, eu_debt_crisis, economic_slowdown_Covid]

for e in events:
    # Highlighting the periods of global economy crises
    start_year = e['Time'].min()
    end_year = e['Time'].max()
    ax.axvspan(xmin=start_year, xmax=end_year, ymin=0, ymax=1, alpha=0.12, color='grey')
    
    # Highlighting the line of each of the crisis
    ax.plot(e['Time'], e['rolling_mean'], linewidth=2.5, color='#9450B3')    


# ----------------------------------------------------------------------------
# Add crisis descriptions

# Adding the `Early 2000s Recession`
ax.text(x=11140, y=1.90, s='Early 2000s', color='#424242', size=12)
ax.text(x=11140, y=1.85, s='Recession', color='#424242', size=12)

# Adding the `Financial Crisis`
ax.text(x=13800, y=1.90, s='Financial', color='#424242', size=12)
ax.text(x=13800, y=1.85, s='Crisis', color='#424242', size=12)

# Adding the `European Sovereign Debt Crisis`
ax.text(x=16640, y=1.90, s='European', color='#424242', size=12)
ax.text(x=16640, y=1.85, s='Sovereign', color='#424242', size=12)
ax.text(x=16640, y=1.80, s='Debt Crisis', color='#424242', size=12)

# Adding the `2019 Global Economic Slowdown and Covid-19 Recession`
ax.text(x=17960, y=1.90, s='Global', color='#424242', size=12)
ax.text(x=17960, y=1.85, s='Economic', color='#424242', size=12)
ax.text(x=17960, y=1.80, s='Slowdown', color='#424242', size=12)
ax.text(x=17960, y=1.75, s='&', color='#424242', size=12)
ax.text(x=17960, y=1.70, s='Covid-19', color='#424242', size=12)
ax.text(x=17960, y=1.65, s='Recession', color='#424242', size=12)


# ----------------------------------------------------------------------------
# Add title
ax.text(x=9900, y=2.20, s='To date, the EURO-USD FX-Rate has not recovered from its 2015 low',
       size=24, weight='bold')

# Add subtitle
ax.text(x=9900, y=2.10, s='EURO-USD FX-rates between 1999 to 2021',
       size=18)

# Add Signature Bar
ax.text(x=9900, y=0.65, s='©SPWong' + ' '*228 + 'Source: European Central Bank',
       color='#ffffff', backgroundcolor='#757575', size=10)

plt.show()

# %% [markdown]
# After the introduction of the euro currency in 1999, the EURO-USD exchange rate plummeted to its lowest point during the **early 2000s recession**. It hit the euro hardest **between 2000 and 2001**, with an exchange rate of 0.8252 in 2000. The value of the euro appreciated rapidly starting from 2002.
#
# During the **financial crisis (2007-2009)**, the EURO-USD exchange rate rose to its record high at 1.5990 in 2008. Nonetheless, it dropped immensely to 1.2555 before rising again to its historical second-highest rate, 1.5120, at the end of the year 2009.
#
# **Between 2015 and 2017**, the EURO-USD exchange rate plummeted rapidly due to multiple factors, such as **the European Central Bank's quantitative easing programme, the deepening of the Greek crisis and the likelihood of an increase in US interest rates** ([Source: The Guardian](https://www.theguardian.com/business/2015/mar/11/euro-12-year-low-gainst-the-dollar)). The EURO-USD rate dropped to its lowest at 1.0364 in 2016. Since then, the value of the euro has not been able to recover to its good old time, i.e. between 2007 and 2014.
#
# The EURO-USD exchange rate suffered again **between 2019 and 2020**. The [major reasons](https://en.wikipedia.org/wiki/COVID-19_recession#2019_global_economic_slowdown) for the **2019 global economic slowdown** were due to **Brexit, China-United States trade war and the potential liquidity crisis**. The EURO-USD rate hit its lowest point at 1.0707 in 2020, during the **Covid-19 recession**, the worst global economic recession caused by the Covid-19 pandemic.

# %% [markdown]
# [Back to Table of Contents](#table-of-contents)

# %% [markdown]
# ---

# %% [markdown]
# ## The evolution of the EURO-USD exchange rate under the last three US presidents

# %% [markdown]
# We are curious to learn about the evolution of the EURO-USD exchange rate under the last three US presidents along with the impact of the historical events/crises.
#
# To do this, we need to group the data of each president based on their serving periods. The US presidents' serving periods are as below:
#
# - Bush: 2001-2009
# - Obama: 2009-2017
# - Trump: 2017-2021

# %%
# Extract the data for each of the presidents
bush = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2001)
                            & (euro_to_dollar['Time'].dt.year < 2009)]

obama = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2009) 
                                & (euro_to_dollar['Time'].dt.year < 2017)]

trump = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2017) 
                                & (euro_to_dollar['Time'].dt.year < 2021)]

# %% [markdown]
# We compute the mean of `rolling_mean`, 1.20, and use it as a guideline for our detailed analysis later.

# %%
euro_to_dollar['rolling_mean'].mean()
# Out:
# 1.1997477484545886

# %% [markdown]
# Let's visualize the data by using line charts with *ggplot* Matplotlib style.

# %%
# Add Matplotlib style
style.use('ggplot')

# Add a line plot
plt.figure(figsize=(12,8))
ax1 = plt.subplot(2,3,1)
ax2 = plt.subplot(2,3,2)
ax3 = plt.subplot(2,3,3)
ax4 = plt.subplot(2,1,2)
axes = [ax1, ax2, ax3, ax4]

# Add spacing between subplots
plt.tight_layout(w_pad=2.0, h_pad=9.0)

# Set the parameters for all plots
for ax in axes:
    ax.set_facecolor(color='#ffffff')  # Set the facecolor of the axis to white
    ax.grid(color='#f0f0f0')  # Change the color of grid to a lighter color
    ax.tick_params(bottom=False, left=False)  # Hide ticks
    ax.set_yticks([0.8, 1.0, 1.2, 1.4, 1.6])  # Reduce the y ticks
    ax.set_ylim(0.8, 1.6)  # Set the y-axis view limits
    ax.tick_params(colors='#9E9E9E', which='both')  # Set tick label color

# Convert the start and end years of the crisis/events during each of the 
# three US presidents's terms to datetime 
years = ['2001', '2003', '2005', '2007', '2009', '2010', '2015', '2017',
        '2018', '2019', '2021']

dt_years = {}

# Add the years in datetime into a dictionary
for year in years:
    dt_year = pd.to_datetime(year)
    dt_years[year] = dt_year

    
# ----------------------------------------------------------------------------
# ax1: Bush
ax1.plot(bush['Time'], bush['rolling_mean'], linewidth=2.5, color='blue')
ax1.set_xticks(['2001', '2003', '2005', '2007', '2009'])
ax1.set_xticklabels(['2001', '2003', '2005', '2007', '2009'])

# Highlight the crisis period during Bush time
# Year 2001 - 2002: early2000s_recessions
ax1.axvspan(xmin=dt_years['2001'], xmax=dt_years['2003'], ymin=0, ymax=0.986, 
            alpha=0.12, color='grey')    
# Year 2007 - 2008: financial_crisis            
ax1.axvspan(xmin=dt_years['2007'], xmax=dt_years['2009'], ymin=0, ymax=0.986, 
            alpha=0.12, color='grey')

# Add title
ax1.text(x=12530, y=1.74, s='Bush',size=14, weight='bold', color='blue')

# Add subtitle
ax1.text(x=12380, y=1.67, s='(2001-2009)', alpha=0.7)


# ----------------------------------------------------------------------------
# ax2: Obama
ax2.plot(obama['Time'], obama['rolling_mean'], linewidth=2.5, color='green')
ax2.set_xticks(['2009', '2011', '2013', '2015', '2017'])
ax2.set_xticklabels(['2009', '2011', '2013', '2015', '2017'])

# Highlight the crisis period during Obama time
# Year 2009: financial_crisis
ax2.axvspan(xmin=dt_years['2009'], xmax=dt_years['2010'], ymin=0, ymax=0.986, 
            alpha=0.12, color='grey') 
# Year 2015 - 2016: European sovereign debt crisis            
ax2.axvspan(xmin=dt_years['2015'], xmax=dt_years['2017'], ymin=0, ymax=0.986, 
            alpha=0.12, color='grey')

# Add title
ax2.text(x=15345, y=1.74, s='Obama',size=14, weight='bold', color='green')

# Add subtitle
ax2.text(x=15300, y=1.67, s='(2009-2017)', alpha=0.7)


# ----------------------------------------------------------------------------
# ax3: Trump
ax3.plot(trump['Time'], trump['rolling_mean'], linewidth=2.5, color='orange')
ax3.set_xticks(['2017', '2018', '2019', '2020', '2021'])
ax3.set_xticklabels(['2017', '2018', '2019', '2020', '2021'])

# Highlight the crisis period during Obama time
# Year 2017: European sovereign debt crisis
ax3.axvspan(xmin=dt_years['2017'], xmax=dt_years['2018'], ymin=0, ymax=0.986, 
            alpha=0.12, color='grey')
# Year 2019 - 2020: 2019 global economic slowdown & Covid-19 recession
ax3.axvspan(xmin=dt_years['2019'], xmax=dt_years['2021'], ymin=0, ymax=0.986, 
            alpha=0.12, color='grey')

# Add title
ax3.text(x=17725, y=1.74, s='Trump',size=14, weight='bold', color='orange')

# Add subtitle
ax3.text(x=17680, y=1.67, s='(2017-2021)', alpha=0.7)


# ----------------------------------------------------------------------------
# ax4: All together
ax4.plot(euro_to_dollar['Time'], euro_to_dollar['rolling_mean'], 
         linewidth=1, color='grey')
ax4.plot(bush['Time'], bush['rolling_mean'], linewidth=2.5, color='blue')      # Bush
ax4.plot(obama['Time'], obama['rolling_mean'], linewidth=2.5, color='green')   # Obama
ax4.plot(trump['Time'], trump['rolling_mean'], linewidth=2.5, color='orange')  # Trump

ax4.set_xticks(['1999', '2001', '2003', '2005', '2007', '2009',
               '2011', '2013', '2015', '2017', '2019', '2021'])
ax4.set_xticklabels(['1999', '2001', '2003', '2005', '2007', '2009',
               '2011', '2013', '2015', '2017', '2019', '2021'])

# Set the y limit
ax4.set_ylim(0.8, 2.0)


# Highlight the period of global economy crisis

events = [early2000s_recessions, financial_crisis, eu_debt_crisis, 
          economic_slowdown_Covid]

for e in events:
    start_year = e['Time'].min()
    end_year = e['Time'].max()
    ax4.axvspan(xmin=start_year, xmax=end_year, ymin=0, ymax=1.0, alpha=0.12, 
                color='grey')

# Add title
ax4.text(x=12630, y=2.22, s='All Together with the Last Three US Presidents',
         size=14, weight='bold', color='Grey')

# Add subtitle
ax4.text(x=14300, y=2.11, s='(1999-2021)', alpha=0.7)

# Add crisis descriptions
# Add the `Early 2000s Recession`
ax4.text(x=11200, y=1.90, s='Early 2000s', color='#424242')
ax.text(x=11200, y=1.83, s='Recession', color='#424242')

# Add the `Financial Crisis`
ax4.text(x=13830, y=1.90, s='Financial', color='#424242')
ax4.text(x=13830, y=1.83, s='Crisis', color='#424242')

# Add the `European Sovereign Debt Crisis`
ax4.text(x=16680, y=1.90, s='European', color='#424242')
ax4.text(x=16680, y=1.83, s='Sovereign', color='#424242')
ax4.text(x=16680, y=1.76, s='Debt Crisis', color='#424242')

# Add the `2019 Global Economic Slowdown and Covid-19 Recession`
ax4.text(x=17990, y=1.90, s='Global', color='#424242')
ax4.text(x=17990, y=1.83, s='Economic', color='#424242')
ax4.text(x=17990, y=1.76, s='Slowdown', color='#424242')
ax4.text(x=17990, y=1.69, s='&', color='#424242')
ax4.text(x=17990, y=1.62, s='Covid-19', color='#424242')
ax4.text(x=17990, y=1.55, s='Recession', color='#424242')


# ----------------------------------------------------------------------------
# For all plots, adding horizontal line for the rolling mean between 1999 - 2021
for ax in axes:
    ax.axhline(xmin=0, xmax=1.00, y=1.20, color='grey', alpha=0.5) 

# Add figure title
ax1.text(x=10800, y=2.02, s="The EURO-USD FX-rate mostly below the FX average during Trump's presidency",
         size=24, weight='bold')

# Add figure subtitle
ax1.text(x=10800, y=1.92, s='EURO-USD FX-rates under US presidents Bush, Obama and Trump', size=18)

# Add Signature Bar
ax.text(x=9900, y=0.55, s='©SPWong' + ' '*203 + 'Source: European Central Bank',
        color='#ffffff', backgroundcolor='#757575', size=10)


plt.show()

# %% [markdown]
# Based on the line plot, we observe that all three US presidents share a similarity — **the start and the end of their terms fall into the highlight of the major events/crises that influenced the EURO-USD exchange rate**.
#
# By using the mean (1.20) of US dollars from 1999 to 2021 as a guideline, we made the following observations:
#
# - **Bush**: Throughout Bush's presidency, **the value of the US dollar against the euro dropped significantly** (i.e. weaker US dollar, stronger euro). At the end of the Bush term, the value of the US dollar bottomed due to the financial crisis and the bursting of the US housing bubble.
#
# - **Obama**: **The value of the US dollar against the euro was generally weak from 2009 to 2015** (i.e. generally stronger euro). In the last two years of Obama's presidency, the US dollar against the euro became stronger — possibly due to the increase of US interest rates, the worsening of the Greece crisis, and the European Central Bank's quantitative easing programme.
#
# - **Trump**: The EURO-USD exchange rate was **relatively stable** throughout Trump's term. The exchange rate below the mean guideline suggests that the value of the US dollar was generally robust. In the final months of Trump's presidency, the value of the US dollar decreased, possibly due to the worsening of the Covid-19 pandemic and recession.

# %% [markdown]
# [Back to Table of Contents](#table-of-contents)

# %% [markdown]
# ---

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this project, we study the evolution of the EURO-USD exchange rate from 1999 to 2021 by using a data visualisation approach. We found that **ever since 2015, the EURO-USD exchange rate has been very weak** — the second weakest period after the early 2000s recession — primarily due to the European Sovereign Debt Crisis. The impact of the financial crisis in 2008 seemed smaller on the EURO currency, instead, it peaked in 2008.
#
# Our findings allow individuals and organisations to better understand and manage their financial risk exposure resulting from dealings in foreign currencies.
#
# Future studies could focus on the effect of Brexit on the EURO-Pound FX-rate and the evolution of the EURO-Yuan FX-rate, as China has been having the second-largest GDP in the world since 2010.
